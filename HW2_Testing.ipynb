# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Networkx Tests

# %%
import networkx as nx
import matplotlib.pyplot as plt
from search import graph

# %%
network_file = './data/tiny_network.adjlist'
tiny_network = nx.read_adjlist('./data/tiny_network.adjlist', create_using=nx.DiGraph, delimiter=";")
tiny_network.nodes()
# Out:
# NodeView(('31806696', 'Luke Gilbert', '31486345', 'Michael Keiser', 'Marina Sirota', '29700475', 'Nevan Krogan', '33765435', '32025019', 'Atul Butte', 'Hani Goodarzi', '34272374', '32353859', '30944313', 'Neil Risch', '33483487', 'Martin Kampmann', '30727954', 'Michael McManus', 'Lani Wu', '32042149', '32036252', '33242416', '31395880', '32790644', 'Steven Altschuler', '31540829', '31626775', 'Charles Chiu', '33232663'))

# %%
list(tiny_network.neighbors('31806696'))
# Out:
# ['Luke Gilbert']

# %%
nx.is_directed(tiny_network)
# Out:
# True

# %%
nx.is_connected(tiny_network)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 nx.is_connected(tiny_network)
#
# File ~/opt/anaconda3/envs/algo/lib/python3.10/site-packages/networkx/utils/decorators.py:766, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     765 def func(*args, __wrapper=None, **kwargs):
# --> 766     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 21:3, in argmap_is_connected_18(G)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/opt/anaconda3/envs/algo/lib/python3.10/site-packages/networkx/utils/decorators.py:86, in not_implemented_for.<locals>._not_implemented_for(g)
#      82 def _not_implemented_for(g):
#      83     if (mval is None or mval == g.is_multigraph()) and (
# ...

# %%
nx.is_weakly_connected(tiny_network)
# Out:
# True

# %%
nx.draw(tiny_network,with_labels=True, font_weight='bold') # Creates visual of node network.
plt.show()

# %%
citation_file = './data/citation_network.adjlist'
citation_network = nx.read_adjlist('./data/citation_network.adjlist', create_using=nx.DiGraph, delimiter=";")
citation_network.nodes()
# Out:
# NodeView(('34916529', '34858697', '34816322', '34803213', '34754064', '34675264', '34669035', '34663617', '34628539', '34599200', '34575370', '34562930', '34552244', '34550967', '34533455', '34514381', '34504303', '34439940', '34398895', '34355695', '34353906', '34321313', '34296183', '34282528', '34262015', '34218182', '34213915', '34187546', '34181648', '34179769', '34177505', '34124652', '34119572', '34085055', '34049495', '34017295', '33979715', '33977131', '33945818', '33828151', '33783217', '33733145', '33720929', '33693052', '33633172', '33623053', '33600850', '33579384', '33563727', '33408613', '33375658', '33332440', '33328947', '33325504', '33304457', '33301712', '33253147', '33252656', '33208805', '33192663', '33183223', '33096023', '33052899', '33028910', '33004996', '32908264', '32797396', '32393820', '32348299', '32327990', '32278089', '32266273', '32155141', '32092054', '32054788', '31999253', '31941884', '31803040', '31767896', '31616273', '31209381', 'Reza Abbasi-Asl
# ...

# %%
list(citation_network.neighbors('31806696'))
# Out:
# ['Luke Gilbert']

# %%
nx.is_directed(citation_network)
# Out:
# True

# %%
nx.shortest_path(citation_network, 'Lani Wu', 'Nevan Krogan')
# Out:
# ['Lani Wu', '29657129', 'Michael McManus', '29961576', 'Nevan Krogan']

# %%
for node in list(nx.nodes(citation_network)):
    if node not in list(nx.bfs_tree(citation_network, "Luke Gilbert")):
        print(node)
# Out:
# 34858697
# 34816322
# 34803213
# 34754064
# 34675264
# 34669035
# 34663617
# 34628539
# 34599200
# 34575370
# 34533455
# 34514381
# 34504303
# 34398895
# 34355695
# 34353906
# 34321313
# 34296183
# 34282528
# 34262015
# 34218182
# 34187546
# 34181648
# 34179769
# 34177505
# 34124652
# 34119572
# 34085055
# 34049495
# 34017295
# 33979715
# 33977131
# 33945818
# 33828151
# 33733145
# 33720929
# 33693052
# 33623053
# 33600850
# 33579384
# 33563727
# 33408613
# 33375658
# 33332440
# 33328947
# 33325504
# 33304457
# 33301712
# 33253147
# 33252656
# 33208805
# 33183223
# 33052899
# 33028910
# 33004996
# 32908264
# 32797396
# 32393820
# 32348299
# 32327990
# 32278089
# 32266273
# 32155141
# 32092054
# 32054788
# 31999253
# 31941884
# 31803040
# 31767896
# 31616273
# 31209381
# Reza Abbasi-Asl
# 31078660
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 2
# ...

# %% [markdown]
# # BFS Example

# %%
graph.Graph(network_file).bfs(start = 'Charles Chiu')
# Out:
# ['Charles Chiu',
#  '33242416',
#  'Atul Butte',
#  '33765435',
#  '31395880',
#  '30944313',
#  'Marina Sirota',
#  'Steven Altschuler',
#  'Lani Wu',
#  'Hani Goodarzi',
#  'Nevan Krogan',
#  '31486345',
#  '32036252',
#  '32042149',
#  '31806696',
#  '30727954',
#  '33232663',
#  '34272374',
#  '32353859',
#  'Michael Keiser',
#  'Luke Gilbert',
#  'Michael McManus',
#  'Martin Kampmann',
#  '33483487',
#  '31626775',
#  '31540829',
#  '32025019',
#  '29700475',
#  '32790644',
#  'Neil Risch']

# %%
graph.Graph(network_file).bfs(start = 'Charles Chiu', end = 'Michael Keiser')
# Out:
# ['Charles Chiu',
#  '33242416',
#  'Atul Butte',
#  '33765435',
#  'Marina Sirota',
#  '31486345',
#  'Michael Keiser']

# %%
graph.Graph(citation_file).bfs('Charles Chiu')
# Out:
# ['Charles Chiu',
#  '34970720',
#  '34970509',
#  '34970259',
#  '34970254',
#  '34966387',
#  '34966365',
#  '34961168',
#  '34960810',
#  '34960803',
#  '34960773',
#  '34960771',
#  '34960755',
#  '34960634',
#  '34959537',
#  '34959518',
#  '34959505',
#  '34957379',
#  '34956212',
#  '34956157',
#  '34955549',
#  '34950723',
#  '34950151',
#  '34947888',
#  '34946059',
#  '34945314',
#  '34944445',
#  '34944332',
#  '34943168',
#  '34941928',
#  '34940245',
#  '34939959',
#  '34937346',
#  '34935114',
#  '34934871',
#  '34934772',
#  '34933045',
#  '34931192',
#  '34931183',
#  '34930148',
#  '34928966',
#  '34927180',
#  '34926323',
#  '34925251',
#  '34924640',
#  '34920374',
#  '34916486',
#  '34915851',
#  '34914928',
#  '34914922',
#  '34914036',
#  '34912791',
#  '34912314',
#  '34911691',
#  '34911583',
#  '34910507',
#  '34909789',
#  '34909777',
#  '34909580',
#  '34908504',
#  '34906597',
#  '34905574',
#  '34905541',
#  '34905151',
#  '34905108',
#  '34905087',
# ...

# %%
list(nx.bfs_tree(tiny_network, "Charles Chiu"))
# Out:
# ['Charles Chiu',
#  '33242416',
#  'Atul Butte',
#  '33765435',
#  '31395880',
#  '30944313',
#  'Marina Sirota',
#  'Steven Altschuler',
#  'Lani Wu',
#  'Hani Goodarzi',
#  'Nevan Krogan',
#  '31486345',
#  '32036252',
#  '32042149',
#  '31806696',
#  '30727954',
#  '33232663',
#  '34272374',
#  '32353859',
#  'Michael Keiser',
#  'Luke Gilbert',
#  'Michael McManus',
#  'Martin Kampmann',
#  '33483487',
#  '31626775',
#  '31540829',
#  '32025019',
#  '29700475',
#  '32790644',
#  'Neil Risch']

# %%
graph.Graph(citation_file).bfs('Lani Wu', 'Nevan Krogan')
# Out:
# ['Lani Wu', '31806696', 'Luke Gilbert', '33382968', 'Nevan Krogan']

# %%
len(nx.shortest_path(citation_network, 'Lani Wu', 'Nevan Krogan')) == len(graph.Graph(citation_file).bfs('Lani Wu', 'Nevan Krogan'))
# Out:
# True

# %%
graph.Graph(citation_file).bfs('Luke Gilbert', '34858697')
